# %%
import os
import re
import glob
import time
import numpy as np
import pandas as pd
import xarray as xr 
import requests
from bs4 import BeautifulSoup
import dotenv
from concurrent.futures import ThreadPoolExecutor, as_completed
dotenv.load_dotenv(dotenv.find_dotenv()) #.env file in the same directory as this script
# Out:
# True

# %% [markdown]
# ### Download FLDAS and GLDAS netcdf files

# %%
# Credentials fo LP DAAC
# you will require an EarthData login
fldas_host = fr"https://hydro1.gesdisc.eosdis.nasa.gov/data/FLDAS/FLDAS_NOAH01_C_GL_M.001/"
gldas_host = fr"https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/"

login = os.getenv('user')
password = os.getenv('pwd')

hosts=[fldas_host,gldas_host]

out_dir =r"D:/VUB/_data/gldas_monthly_data"
if not os.path.exists(out_dir):
    os.makedirs(out_dir)

# %% [markdown]
# #### FLDAS Files

# %%
# list folders from which to download
r = requests.get(gldas_host, verify=True, stream=True,auth=(login,password))

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(r.text, "html.parser")
folders = list()
for link in soup.findAll('a', attrs={'href': re.compile("\d{4}/")}): #e.g. 2000/ #fldas
    # Append unique links to the list
    href = link.get('href')
    if href not in folders:
        folders.append(href)
print(f"{len(folders)} folders found")
# Out:
# 0 folders found

# %%
#subset of data to download
subset_folders=folders[0:2]
subset_folders
# Out:
# ['1982/', '1983/']

# %% [markdown]
# #### GLDAS files with concurrent features

# %%
# Year range
year_folders = np.arange(2004, 2024)  # ['2004/', '2005/', ... '2023/']

# Manually decode the months
months = [f"{str(i).zfill(2)}/" for i in range(1, 13)]  # ['01/', '02/', ... '12/']

exceptions = list()

def download_file(url, local_path):
    try:
        r = requests.get(url, verify=True, stream=True, auth=(login, password), timeout=60)
        r.raise_for_status()
        with open(local_path, "wb") as f:
            f.write(r.content)
        print(f"Downloaded {local_path}", end='\r')
    except Exception as error:
        print(f"Error downloading {url}: {error}")
        exceptions.append(url)

# Use ThreadPoolExecutor for concurrent downloads
with ThreadPoolExecutor(max_workers=6) as executor:  # Adjust max_workers based on your bandwidth
    futures = []
    
    for year_folder in year_folders:
        for month in months:
            month_url = f"{gldas_host}{year_folder}/{month}"
            r = requests.get(month_url, verify=True, stream=True, auth=(login, password))
            
            if r.status_code == 200:
                soup = BeautifulSoup(r.text, "html.parser")
                
                for link in soup.findAll('a', attrs={'href': re.compile(r'\.nc4$')}):
                    file_name = link.get('href')
                    full_file_path = f"{month_url}{file_name}"
                    local_filename = file_name.split("/")[-1]
                    local_path = f"{out_dir}/{local_filename}"
                    
                    # Submit the download task to the ThreadPoolExecutor
                    futures.append(executor.submit(download_file, full_file_path, local_path))
            else:
                print(f"Failed to access {month_url}, status code: {r.status_code}", end='\r')
        
        # Pause after processing each year
        print(f"Processed year {year_folder}, pausing for 5 seconds...", end='\r')
        time.sleep(5)

    # Wait for all futures to complete
    for future in as_completed(futures):
        future.result()  # To raise any exceptions that occurred during download

# Optional: print or log exceptions
if exceptions:
    print(f"Some files could not be downloaded. Check the following paths:")
    for path in exceptions:
        print(path)
# Out:
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/06/GLDAS_CLSM025_DA1_D.A20
>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040723.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040723.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C7737B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040722.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040722.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C7739B210>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040724.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040724.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C6FC7CB90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040725.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040725.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C7743DF90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040724.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040724.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C71E26210>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040725.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040725.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C71E25F10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040726.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040726.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C7722B4D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040726.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040726.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C77399F10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040727.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040727.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C772BD750>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040727.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040727.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C71E35950>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040728.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040728.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C77509050>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040728.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040728.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C77349A90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040729.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040729.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C7743EED0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040729.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2004/07/GLDAS_CLSM025_DA1_D.A20040729.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C7743CB50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# ...
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110907.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110907.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C71F03250>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110908.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110908.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C71F01BD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110909.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110909.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C71D8FF50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110908.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110908.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C72481390>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110909.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110909.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C725E39D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110910.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110910.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C6FBD8C10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110910.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110910.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C72769AD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110911.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110911.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C6EAB2490>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110911.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110911.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C72B38590>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110912.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110912.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C72297910>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110913.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110913.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C72481410>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110913.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110913.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C72B0C590>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110912.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110912.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C6E393DD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110914.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110914.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C7276AA10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110914.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110914.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C71D8F050>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110915.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110915.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C71E52B90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110916.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110916.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C7294DB50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110916.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110916.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C71D8DB90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110917.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110917.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C72445E50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110915.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110915.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C72150250>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110917.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110917.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C6EAB2490>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110919.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110919.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C725E39D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110919.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110919.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C72294D50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110920.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110920.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C71CAA510>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110918.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110918.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C71D8E1D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110918.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110918.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C7276AAD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110920.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110920.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C72BD9290>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110921.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110921.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C72BD8C50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110921.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110921.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C72481410>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110922.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110922.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C71F03D90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110922.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110922.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C72446CD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Error downloading https://hydro1.gesdisc.eosdis.nasa.gov/data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110923.022.nc4: HTTPSConnectionPool(host='hydro1.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /data/GLDAS/GLDAS_CLSM025_DA1_D.2.2/2011/09/GLDAS_CLSM025_DA1_D.A20110923.022.nc4 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C72446250>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Downloaded D:/VUB/_data/gldas_monthly_data/GLDAS_CLSM025_DA1_D.A20110923.022.nc4

# %% [markdown]
# #### FLDAS files

# %%
# Initialize a list to keep track of any exceptions
exceptions = list()

# Loop through folders and process files
for folder in subset_folders:
    folder_url = f"{fldas_host}/{folder}"
    r = requests.get(folder_url, verify=True, stream=True, auth=(login, password))
    soup = BeautifulSoup(r.text, "html.parser")
    
    for link in soup.findAll('a', attrs={'href': re.compile(".nc4$")}):
        file_name = link.get('href')
        full_file_path = f"{folder_url}/{file_name}"  # Concatenate folder and file

        local_filename = full_file_path.split('/')[-1]
        print(f"Downloading {local_filename}", end='\r')
        
        try:
            # Make the request to download the file
            r = requests.get(full_file_path, verify=True, stream=True, auth=(login, password))
            
            # Save the file with its original name in the specified directory
            local_path = f"{out_dir}/{local_filename}"
            
            with open(local_path, "wb") as f:
                f.write(r.content)
        
        except Exception as error:
            print(f"Error downloading {full_file_path}: {error}", end='\r')
            exceptions.append(full_file_path)
    
    # Pause every 10 folders to avoid overloading the server
    if (folders.index(folder) + 1) % 10 == 0:
        print(f"Processed {folders.index(folder) + 1} folders, pausing for 5 seconds...", end='\r')
        time.sleep(5)

print("\n" f"Download process completed with {len(exceptions)} exceptions")

# %% [markdown]
# #### Extract ROI

# %%
#Read files
files = glob.glob(r'D:\VUB\_data\fldas_monthly_data/*.nc')

min_lat = -1.75
max_lat = 5.55
min_lon = 33.75
max_lon = 40.75

ds_list=[]
for file in files[:]:
    files.sort()
    ds=xr.open_dataset(file)
    #extract the region of interest
    ds_roi=ds.sel(X=slice(min_lon, max_lon),Y=slice(min_lat,max_lat)) #this is the order of coordinates that works to clip the data

    #rename coordinates
    ds_roi=ds_roi.rename({'X':'lon','Y':'lat'})

    ds_list.append(ds_roi)

ds_all=xr.concat(ds_list,dim='time')

# %%
ds_all.to_netcdf(r'D:\VUB\_data\fldas_monthly_data\fldas_all_vars_2000_2023.nc')

# %%
ds_all
# Out:
# <xarray.Dataset>
# Dimensions:                 (lon: 70, lat: 74, time: 576, bnds: 2)
# Coordinates:
#   * lon                     (lon) float64 33.75 33.85 33.95 ... 40.55 40.65
#   * lat                     (lat) float64 -1.75 -1.65 -1.55 ... 5.35 5.45 5.55
#   * time                    (time) datetime64[ns] 2023-01-01 ... 2012-12-01
# Dimensions without coordinates: bnds
# Data variables: (12/29)
#     time_bnds               (time, bnds) datetime64[ns] 2023-01-01 ... 2013-0...
#     Evap_tavg               (time, lat, lon) float32 4.304e-05 4.501e-05 ... nan
#     LWdown_f_tavg           (time, lat, lon) float32 363.4 360.7 ... nan nan
#     Lwnet_tavg              (time, lat, lon) float32 -72.84 -72.44 ... nan nan
#     Psurf_f_tavg            (time, lat, lon) float32 8.798e+04 8.731e+04 ... nan
#     Qair_f_tavg             (time, lat, lon) float32 0.01195 0.01163 ... nan nan
#     ...                      ...
#     SoilMoi40_100cm_tavg    (time, lat, lon) float32 0.2504 0.2668 ... nan nan
#     SoilMoi100_200cm_tavg   (time, lat, lon) float32 0.3525 0.3508 ... nan nan
#     SoilTemp00_10cm_tavg    (time, lat, lon) float32 296.9 296.4 ... nan nan
#     SoilTemp10_40cm_tavg    (time, lat, lon) float32 296.2 295.7 ... nan nan
#     SoilTemp40_100cm_tavg   (time, lat, lon) float32 295.9 295.4 ... nan nan
#     SoilTemp100_200cm_tavg  (time, lat, lon) float32 295.6 295.1 ... nan nan
# Attributes: (12/19)
#     CDI:                        Climate Data Interface version 1.9.1 (http://...
#     history:                    Sat Feb 18 15:11:02 2023: cdo -z zip_4 replac...
#     institution:                NASA GSFC
#     Conventions:                CF-1.6
#     missing_value:              -9999.0
#     NUM_SOIL_LAYERS:            4
#     ...                         ...
#     SOUTH_WEST_CORNER_LON:      -179.95
#     DX:                         0.1
#     DY:                         0.1
#     history_of_appended_files:  Sat Feb 18 12:16:49 2023: Appended file time_...
#     NCO:                        netCDF Operators version 4.8.1 (Homepage = ht...
#     CDO:                        Climate Data Operators version 1.9.1 (http://...
